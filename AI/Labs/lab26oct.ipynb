# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> Pandas </h1>

# %%
#series, one dimensional structure
s = pd.Series([2, 4, -12, 0, 2])

# %%
s
# Out:
# 0     2
# 1     4
# 2   -12
# 3     0
# 4     2
# dtype: int64

# %%
s.shape
# Out:
# (5,)

# %%
s.dtype
# Out:
# dtype('int64')

# %%
#convert it into a numpy array with s.values
s.values
# Out:
# array([  2,   4, -12,   0,   2])

# %%
s[3]
# Out:
# 0

# %%
#slicing in python
s[1:3]
# Out:
# 1     4
# 2   -12
# dtype: int64

# %%
s[1:]
# Out:
# 1     4
# 2   -12
# 3     0
# 4     2
# dtype: int64

# %%
s * 2
# Out:
# 0     4
# 1     8
# 2   -24
# 3     0
# 4     4
# dtype: int64

# %%
s > 0
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
#take the elements which are > 0
s[s > 0]
# Out:
# 0    2
# 1    4
# 4    2
# dtype: int64

# %%
#sum of elements
s.sum()
# Out:
# -4

# %%
#average
s.mean()
# Out:
# -0.80000000000000004

# %%
#unique values
s.unique()
# Out:
# array([  2,   4, -12,   0])

# %%
#Dataframe structure - it's like a matrix
df = pd.DataFrame({'a' : [1, 2, 3], 'b' : [4, 5, 6], 'c' : [7, 8 ,9]})

# %%
#keys become column names
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df = pd.read_csv('datasets/dataset_corkA.csv')

# %%
df
# Out:
#      flarea           type  bdrms  bthrms  floors     devment ber  \
# 0     497.0       Detached      4       5       2  SecondHand  B2
# 1      83.6       Detached      3       1       1  SecondHand  D2
# 2      97.5  Semi-detached      3       2       2  SecondHand  D1
# 3     158.0  Semi-detached      5       2       2  SecondHand  C3
# 4     118.7  Semi-detached      3       2       2  SecondHand  E2
# 5     170.0       Detached      4       4       2  SecondHand  D1
# 6      97.5  Semi-detached      3       2       2  SecondHand  C3
# 7     123.6  Semi-detached      4       2       2  SecondHand  C1
# 8     137.5       Detached      5       2       2  SecondHand  C2
# 9      48.3      Apartment      1       1       1  SecondHand  C1
# 10    197.9  Semi-detached      4       3       2  SecondHand  C3
# 11    102.0       Terraced      3       1       2  SecondHand   G
# 12    122.6  Semi-detached      3       3       2  SecondHand  B3
# ...

# %%
df.shape
# Out:
# (207, 9)

# %%
df.dtypes
# Out:
# flarea      float64
# type         object
# bdrms         int64
# bthrms        int64
# floors        int64
# devment      object
# ber          object
# location     object
# price         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['flarea', 'type', 'bdrms', 'bthrms', 'floors', 'devment', 'ber',
#        'location', 'price'],
#       dtype='object')

# %%
df.describe(include = 'all')
# Out:
#             flarea           type       bdrms      bthrms      floors  \
# count   207.000000            207  207.000000  207.000000  207.000000
# unique         NaN              4         NaN         NaN         NaN
# top            NaN  Semi-detached         NaN         NaN         NaN
# freq           NaN             65         NaN         NaN         NaN
# mean    128.094686            NaN    3.434783    2.106280    1.826087
# std      73.970582            NaN    1.232390    1.185802    0.379954
# min      41.800000            NaN    1.000000    1.000000    1.000000
# 25%      82.650000            NaN    3.000000    1.000000    2.000000
# 50%     106.000000            NaN    3.000000    2.000000    2.000000
# 75%     153.650000            NaN    4.000000    3.000000    2.000000
# max     497.000000            NaN   10.000000   10.000000    2.000000
#
#            devment  ber    location       price
# count          207  207         207  207.000000
# ...

# %%
#it is stored like a series - one dimensional structure
df['type']
# Out:
# 0           Detached
# 1           Detached
# 2      Semi-detached
# 3      Semi-detached
# 4      Semi-detached
# 5           Detached
# 6      Semi-detached
# 7      Semi-detached
# 8           Detached
# 9          Apartment
# 10     Semi-detached
# 11          Terraced
# 12     Semi-detached
# 13          Detached
# 14          Detached
# 15          Detached
# 16          Terraced
# 17          Terraced
# 18          Terraced
# 19     Semi-detached
# 20          Detached
# 21         Apartment
# 22          Detached
# 23     Semi-detached
# 24     Semi-detached
# 25     Semi-detached
# 26          Terraced
# 27          Terraced
# 28         Apartment
# 29         Apartment
#            ...
# 177         Detached
# 178         Detached
# 179         Terraced
# 180    Semi-detached
# 181    Semi-detached
# 182         Detached
# 183    Semi-detached
# 184         Terraced
# 185        Apartment
# 186         Detached
# 187         Detached
# 188         Detached
# ...

# %%
df['type'].unique()
# Out:
# array(['Detached', 'Semi-detached', 'Apartment', 'Terraced'], dtype=object)

# %%
#dataframe structure
df[['type', 'location']]
# Out:
#               type       location
# 0         Detached   Carrigrohane
# 1         Detached       Glanmire
# 2    Semi-detached       Glanmire
# 3    Semi-detached        Douglas
# 4    Semi-detached        Douglas
# 5         Detached        Douglas
# 6    Semi-detached     CityCentre
# 7    Semi-detached  Silversprings
# 8         Detached    PassageWest
# 9        Apartment    Ballinlough
# 10   Semi-detached        Douglas
# 11        Terraced      Farranree
# 12   Semi-detached       Glanmire
# 13        Detached       Glanmire
# 14        Detached     Rochestown
# 15        Detached     Inniscarra
# 16        Terraced    PassageWest
# 17        Terraced     CityCentre
# 18        Terraced     CityCentre
# 19   Semi-detached       Glanmire
# 20        Detached      Waterfall
# 21       Apartment        Douglas
# 22        Detached        Douglas
# 23   Semi-detached      Blackrock
# 24   Semi-detached        Douglas
# 25   Semi-detached        Douglas
# ...

# %%
#print a row
df.ix[4]
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# flarea              118.7
# type        Semi-detached
# bdrms                   3
# bthrms                  2
# floors                  2
# devment        SecondHand
# ber                    E2
# location          Douglas
# price                 380
# Name: 4, dtype: object

# %%
df['type'] == 'Apartment'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29      True
#        ...
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185     True
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194     True
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# 205    False
# 206    False
# Name: type, Length: 207, dtype: bool

# %%
df[df['type'] == 'Apartment']
# Out:
#      flarea       type  bdrms  bthrms  floors     devment ber       location  \
# 9      48.3  Apartment      1       1       1  SecondHand  C1    Ballinlough
# 21     83.6  Apartment      2       2       1  SecondHand  D2        Douglas
# 28     65.0  Apartment      2       2       1  SecondHand  B2     CityCentre
# 29     90.0  Apartment      2       2       1  SecondHand  B3      Blackrock
# 31    117.0  Apartment      2       3       2  SecondHand  B3     Rochestown
# 47     66.0  Apartment      2       1       1  SecondHand  E1         Wilton
# 50     57.0  Apartment      2       1       1  SecondHand  D1     CityCentre
# 52     67.0  Apartment      2       2       1  SecondHand  B3      Blackrock
# 56     60.0  Apartment      2       1       1  SecondHand  C1     CityCentre
# 65     70.0  Apartment      2       1       1  SecondHand  B2      Blackrock
# 66     51.1  Apartment      1       1       1  SecondHand  C1      Blackrock
# ...

# %%
#and, or and not
#&  | ~
df[(df['type'] == 'Apartment') | (df['type'] == 'Terraced')]
# Out:
#      flarea       type  bdrms  bthrms  floors     devment ber       location  \
# 9      48.3  Apartment      1       1       1  SecondHand  C1    Ballinlough
# 11    102.0   Terraced      3       1       2  SecondHand   G      Farranree
# 16    101.9   Terraced      3       3       2  SecondHand  B3    PassageWest
# 17     60.0   Terraced      3       1       2  SecondHand   F     CityCentre
# 18     81.8   Terraced      4       2       2  SecondHand  C3     CityCentre
# 21     83.6  Apartment      2       2       1  SecondHand  D2        Douglas
# 26     66.9   Terraced      3       1       2  SecondHand  D2        Douglas
# 27     78.0   Terraced      3       1       2  SecondHand  E1     CityCentre
# 28     65.0  Apartment      2       2       1  SecondHand  B2     CityCentre
# 29     90.0  Apartment      2       2       1  SecondHand  B3      Blackrock
# 30    120.0   Terraced      4       2       2  SecondHand  D2     CityCentre
# ...

# %%
#how many apartments
#here you extract the rows
df[df['type'] == 'Apartment'].shape
# Out:
# (27, 9)

# %%
#here you extract the rows
len(df[df['type'] == 'Apartment'])
# Out:
# 27

# %%
#the fastest - only boolean values
(df['type'] == 'Apartment').sum()
# Out:
# 27

# %%
#shuffle the data
m, n = df.shape

# %%
np.random.permutation(m)
# Out:
# array([ 72, 138,  39,  56, 102, 171,  59,  29,  10, 160,  74, 140,   7,
#        137, 196,  47,  42,  30, 178, 100, 135, 113,  15,  32,  89, 149,
#        200,  16,  31,  90,   4,   6, 130, 107,  65, 193, 167,  19, 133,
#         61,  96, 118,  68, 128, 194, 188,  52, 121,  11, 115,  55,  83,
#        108, 199, 112,  71,  44, 153, 109, 195,  80,  24, 116, 158,   3,
#        155,  53,   1, 142,  82, 126, 136,  60, 114, 122, 123, 174, 172,
#         36,  58,  98, 148,  33, 104, 129, 117, 119, 175, 169, 173, 204,
#         69,  14,  75, 203, 151, 192,  95, 176,  77,  35,  81,  20,  23,
#        165,  46,  27, 103,  62, 161, 139,   0, 134, 163, 201, 197,  85,
#        186,  50,  93, 198,  84, 147, 150, 187, 131, 191, 162,  86,  40,
#        177, 101,  63,  97, 168, 190, 180,  22,  76,  38,  78,  54, 154,
#         26, 166,  70,  41,  91, 185, 170, 120,   5,  94,  57,  48,  43,
#        111,  17, 183,  45, 105,  12,  51, 124,  13, 143,   2,  67,  92,
# ...

# %%
df = df.take(np.random.permutation(m))

# %%
df
# Out:
#      flarea           type  bdrms  bthrms  floors     devment ber  \
# 49     97.5  Semi-detached      3       3       2  SecondHand  C3
# 159   204.4       Terraced      8       5       2  SecondHand   G
# 0     497.0       Detached      4       5       2  SecondHand  B2
# 133   139.4       Detached      3       2       2  SecondHand  B3
# 183   102.2  Semi-detached      5       2       2  SecondHand  D2
# 147   130.1       Detached      3       2       2  SecondHand  C1
# 88     69.7       Terraced      3       1       2  SecondHand  D2
# 173   158.0       Terraced      4       2       2  SecondHand   F
# 172   128.0       Detached      4       1       2  SecondHand  D1
# 182   161.0       Detached      3       2       2  SecondHand   G
# 139   246.0       Detached      6       3       2  SecondHand  C1
# 38     95.0  Semi-detached      3       3       2  SecondHand  C1
# 121   203.5       Detached      5       3       2  SecondHand  C1
# ...

# %%
#very important function in pandas after you change the order of rows
#don't forget to put it
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      flarea           type  bdrms  bthrms  floors     devment ber  \
# 0      97.5  Semi-detached      3       3       2  SecondHand  C3
# 1     204.4       Terraced      8       5       2  SecondHand   G
# 2     497.0       Detached      4       5       2  SecondHand  B2
# 3     139.4       Detached      3       2       2  SecondHand  B3
# 4     102.2  Semi-detached      5       2       2  SecondHand  D2
# 5     130.1       Detached      3       2       2  SecondHand  C1
# 6      69.7       Terraced      3       1       2  SecondHand  D2
# 7     158.0       Terraced      4       2       2  SecondHand   F
# 8     128.0       Detached      4       1       2  SecondHand  D1
# 9     161.0       Detached      3       2       2  SecondHand   G
# 10    246.0       Detached      6       3       2  SecondHand  C1
# 11     95.0  Semi-detached      3       3       2  SecondHand  C1
# 12    203.5       Detached      5       3       2  SecondHand  C1
# ...

# %% [markdown]
# <h1>Exercise</h1>

# %%
df = pd.read_csv('datasets/dataset_stop_and_searchB.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-64-7333d918a084> in <module>()
# ----> 1 df = pd.read_csv('datasets/dataset_stop_and_searchB.csv')
#
# ...

# %% [markdown]
# <p>Are Thamves Valley Police racist? (using pandas)</p>
